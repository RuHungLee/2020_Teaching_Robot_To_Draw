# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
path = './out_test'
img_list = os.listdir(path)

# %%
test_img = os.path.join(path , img_list[0] , 'predict.jpg')
img = cv2.imread(test_img , cv2.COLOR_BGR2GRAY)
import matplotlib.pyplot as plt
img = img*3.5
index = np.argmax(img) 
x = index//109
y = index%109
img[x][y] = 255
plt.imshow(img)

# %%
# Out:
# 5064

# %%
# Out:
# 50
